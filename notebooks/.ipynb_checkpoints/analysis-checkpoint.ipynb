# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from growth.sweep.sweep import Sweep

# %%
ls ../simulations/
# Out:
# sweep_111818_no_history/           sweep_111918_growth_p1/
# sweep_111818_with_history/         sweep_111918_growth_p5/
# sweep_111918/                      sweep_111918_new_format/
# sweep_111918_fraction_recombining/

# %%
path = '../simulations/sweep_111918_new_format/'
sweep = Sweep.load(path)

# %%
import matplotlib.pyplot as plt

# %%
replicate_id = 0

row_size = sweep.density * sweep.batch_size
col_size = sweep.batch_size


fig, axes = plt.subplots(nrows=sweep.density, ncols=sweep.density, figsize=(25, 25))

ax_id = 0
for index in range(sweep.N):
    if (index % sweep.batch_size) != replicate_id:
        continue
    
    # load simulation
    sim = sweep[index]

    # plot culture
    ax = axes.flatten()[ax_id]
    sim.plot(ax=ax, s=10)

    start_point = sim.recombination_start / sim.final_population
    ax.set_title('Start: {:0.2f}\nRecombination {:0.2f}'.format(start_point, sim.recombination), fontsize=8)
    ax.axis('off')

    # increment ax_id
    ax_id += 1

# %%
index = 20
replicate_id = 0
sim = sweep[index*sweep.batch_size+replicate_id]

# %%
sim.plot()

# %%
sim.clones.
# Out:
# 3

# %%
# for i, sim in enumerate(sweep):
#     sim.recombination_start = sweep.parameters[i, 0]

# %%
sweep.aggregate()
# Out:
# /Users/Sebi/.virtualenvs/growth/lib/python3.6/site-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/Sebi/.virtualenvs/growth/lib/python3.6/site-packages/numpy/core/_methods.py:110: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Users/Sebi/.virtualenvs/growth/lib/python3.6/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/Sebi/.virtualenvs/growth/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/Sebi/.virtualenvs/growth/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
sweep.results['mean_clone_size'] = sweep.results.population / sweep.results.num_clones
sweep.results['start_time'] = sweep.results.recombination_start / sweep.results.population

# %%
sweep.results.groupby(['row', 'column']).mean()
# Out:
#             clone_size_variation  division_rate  num_clones  \
# row column
# 0   0                   0.894351            0.1         5.0
#     1                   0.603088            0.1         4.7
#     2                   0.338960            0.1         3.2
#     3                   0.142740            0.1         2.2
#     4                   0.108023            0.1         3.8
# 1   0                   1.562095            0.1        11.4
#     1                   0.799634            0.1        16.9
#     2                   0.555979            0.1        14.7
#     3                   0.404574            0.1        11.8
#     4                   0.248286            0.1        12.9
# 2   0                   1.808869            0.1        20.7
#     1                   0.902709            0.1        40.2
#     2                   0.653624            0.1        42.4
#     3                   0.549702            0.1        43.8
#     4                   0.282183            0.1        39.9
# 3   0                   1.577278            0.1         9.4
#     1                   1.072013            0.1        79.0
#     2                   0.795437            0.1        89.5
#     3                   0.609087            0.1       108.9
#     4                   0.384573            0.1       109.7
# 4   0                   1.071352            0.1         4.7
#     1                   1.461024            0.1        70.0
#     2                   1.118439            0.1       142.1
#     3                   0.821470            0.1       200.3
#     4                   0.630811            0.1       247.1
#
#             percent_heterozygous  population  recombination_duration  \
# row column
# 0   0                   0.904012      1062.3                   200.0
#     1                   0.986537      1052.3                   200.0
#     2                   0.993580      1058.1                   200.0
#     3                   0.997567      1039.1                   200.0
#     4                   0.996034      1031.9                   200.0
# 1   0                   0.728639      1045.8                   200.0
#     1                   0.956186      1053.8                   200.0
#     2                   0.972806      1046.4                   200.0
#     3                   0.984360      1057.8                   200.0
#     4                   0.986100      1049.2                   200.0
# 2   0                   0.468881      1044.5                   200.0
#     1                   0.868776      1062.5                   200.0
#     2                   0.920917      1058.3                   200.0
#     3                   0.939186      1054.8                   200.0
#     4                   0.957702      1044.4                   200.0
# 3   0                   0.045365      1049.6                   200.0
#     1                   0.662506      1070.6                   200.0
#     2                   0.789964      1041.8                   200.0
#     3                   0.832706      1043.5                   200.0
#     4                   0.876407      1054.5                   200.0
# 4   0                   0.000000      1038.9                   200.0
#     1                   0.223069      1049.6                   200.0
#     2                   0.423115      1053.2                   200.0
#     3                   0.562459      1061.7                   200.0
#     4                   0.629942      1044.0                   200.0
#
#             recombination_rate  recombination_start  replicate  \
# row column
# 0   0                 0.010000                  0.0        4.5
#     1                 0.010000                200.0        4.5
#     2                 0.010000                400.0        4.5
#     3                 0.010000                600.0        4.5
#     4                 0.010000                800.0        4.5
# 1   0                 0.031623                  0.0        4.5
#     1                 0.031623                200.0        4.5
#     2                 0.031623                400.0        4.5
#     3                 0.031623                600.0        4.5
#     4                 0.031623                800.0        4.5
# 2   0                 0.100000                  0.0        4.5
#     1                 0.100000                200.0        4.5
#     2                 0.100000                400.0        4.5
#     3                 0.100000                600.0        4.5
#     4                 0.100000                800.0        4.5
# 3   0                 0.316228                  0.0        4.5
#     1                 0.316228                200.0        4.5
#     2                 0.316228                400.0        4.5
#     3                 0.316228                600.0        4.5
#     4                 0.316228                800.0        4.5
# 4   0                 1.000000                  0.0        4.5
#     1                 1.000000                200.0        4.5
#     2                 1.000000                400.0        4.5
#     3                 1.000000                600.0        4.5
#     4                 1.000000                800.0        4.5
#
#             transclone_edges  mean_clone_size  start_time
# row column
# 0   0               0.158454              inf    0.000000
#     1               0.047591              inf    0.190152
#     2               0.024799       388.708333    0.378253
#     3               0.011081              inf    0.577860
#     4               0.017891              inf    0.775779
# 1   0               0.339704       111.960889    0.000000
#     1               0.154627        66.318713    0.189861
#     2               0.109272        84.563107    0.382548
#     3               0.070767       140.625913    0.567583
#     4               0.064531       103.870682    0.762811
# 2   0               0.528381        56.107011    0.000000
#     1               0.427023        27.649349    0.188372
#     2               0.322512        25.957694    0.378235
#     3               0.269102        24.803442    0.569209
#     4               0.195284        27.178697    0.766706
# 3   0               0.367061       173.897995    0.000000
#     1               0.941768        13.698962    0.186918
#     2               0.757192        11.770047    0.384413
#     3               0.695218         9.683957    0.575373
#     4               0.552472         9.788611    0.759315
# 4   0               0.198418       273.406429    0.000000
#     1               1.356301        15.067507    0.190621
#     2               1.552482         7.433336    0.379971
#     3               1.489712         5.332898    0.565494
#     4               1.400564         4.240050    0.766906

# %%
df = sweep.results[sweep.results.replicate==1]

# %%
import numpy as np

# %%
shape = (sweep.density, sweep.density)
xx = df.start_time.values.reshape(shape)
yy = df.recombination_rate.values.reshape(shape)
zz_extent = 1-df.percent_heterozygous.values.reshape(shape)
zz_num_clones = df.num_clones.values.reshape(shape)

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(8, 3))
ax0.imshow(zz_extent, cmap=plt.cm.viridis)
ax0.set_title('Recombination extent')
ax1.imshow(zz_num_clones, cmap=plt.cm.viridis)
ax1.set_title('Number of clones')

for ax in (ax0, ax1):
    ax.invert_yaxis()
    ax.set_xlabel('Recombination Start')
    ax.set_ylabel('Recombination Rate')
    _ = ax.set_xticklabels(['']+['{:0.1%}'.format(l) for l in xx[0]]+[''])
    _ = ax.set_yticklabels(['']+['{:0.2f}'.format(l) for l in yy[:,0]]+[''])

# %%
_ = plt.hist(zz.flatten())

# %%
[l for l in ax.get_xticklabels()]
# Out:
# [Text(-1.0, 0, '0.000244140625'),
#  Text(0.0, 0, '0.001220703125'),
#  Text(1.0, 0, '0.006591796875'),
#  Text(2.0, 0, '0.035888671875'),
#  Text(3.0, 0, '0.189453125'),
#  Text(4.0, 0, '1.0'),
#  Text(5.0, 0, ''),
#  Text(6.0, 0, '')]

# %%
"""
Want to test:
    1. Heterogeneity/Mixing
    2. Fluorescence spectral overlap

METRICS:
    1. mean size of a connected component
    2. number of connected components
    3. % heterogeneous


A: Plot heatmaps of each metric for growth vs recombination rate


"""

# %%
import sys
p = '../clones_dev/'
if p not in sys.path:
    sys.path.insert(0, p)

# %%
from clones.spatial.graphs import Graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-145-fb7de778f311> in <module>
# ----> 1 from clones.spatial.graphs import Graph
#
# ~/Documents/grad_school/research/growth/clones_dev/clones/spatial/graphs.py in <module>
#       6 from collections import Counter
#       7
# ----> 8 from .infomap import InfoMap
#       9
#      10
#
# ~/Documents/grad_school/research/growth/clones_dev/clones/spatial/infomap.py in <module>
#       1 import numpy as np
# ----> 2 import infomap
#       3
#       4
#       5 class InfoMap:
#
# ModuleNotFoundError: No module named 'infomap'

# %% [markdown]
# # Simulation video

# %%
# %%capture
lineage_video = culture.animate(interval=200, colorby='lineage', cmap=plt.cm.rainbow, repeat_delay=5000)
genotype_video = culture.animate(interval=200, colorby='genotype', cmap=plt.cm.viridis, repeat_delay=5000)

# %%
# play video
HTML(genotype_video)
# Out:
# <video width="360" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
culture.fluorescence.show_pdf()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-161-298d42f5a428> in <module>
# ----> 1 culture.fluorescence.show_pdf()
#
# ~/Documents/grad_school/research/growth/growth/fluorescence.py in show_pdf(self, xlim)
#      63
#      64         # plot component distributions
# ---> 65         pdf = np.zeros(self.support.size, dtype=np.float64)
#      66         for i in range(3):
#      67             rv = st.gamma(self.shape[i], loc=self.loc[i], scale=self.scale[i])
#
# AttributeError: 'Fluorescence' object has no attribute 'support'

# %%
culture = culture.branch()

# %%
culture.freeze(-1).plot(colorby='phenotype', cmap=plt.cm.Greys)

# %%
phylogeny = culture.phylogeny

# %%
# sweep fluorecence functions (can permute with growth)

# %%
colony size

colony heterogeneity (recombination rate)

# %%
ls
# Out:
# development.ipynb

# %%
import scipy.stats as st

# %%
from growth.fluorescence import Fluorescence

# %%
fluor = Fluorescence(shape=(0.5, 5, 10), loc=(0, 2, 5), density=100000)
fluor.show_pdf()

# %%
branch = culture.freeze(25)

# %%
from ete3 import Tree, TreeStyle

# %%
t = Tree(branch.phylogeny.newick)
#t.populate(10, random_branches=True)
ts = TreeStyle()
ts.show_leaf_name = False
ts.scale = 10
ts.show_scale = False
ts.min_leaf_separation = 10
ts.show_branch_support = True

#ts.scale =  10 # 120 pixels per branch length unit
t.render("%%inline", tree_style=ts, h=10, w=5, units='in')

# %%
lim = (-1.2, 1.2)

xr = np.linspace(*lim, num=1000)
xx, yy = np.meshgrid(*(xr,)*2)
zz = griddata(pop.xy, pop.genotypes, (xx, yy), method='nearest')
mask = griddata(pop.xy, pop.genotypes, (xx, yy), method='linear')
zz = np.ma.masked_array(zz, mask=np.isnan(mask))

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.imshow(np.flipud(zz), extent=lim+lim)

pop.plot(ax=ax, s=5)
ax2.set_aspect(1)

#ax.contour(zz.data==2, )
ax.axis('on')
# Out:
# (-1.2, 1.2, -1.2, 1.2)

# %%
from sklearn.neighbors import KernelDensity

# %%
kde = KernelDensity().fit(pop.xy)

# %%
density = kde.score_samples(np.stack((xx,yy)).T.reshape(-1, 2))

# %%
# Out:
# (1000, 1000)

# %%
def _evaluate_max_edge_lengths(self):
    """ Returns max edge length per triangle. """
    merge = lambda x: np.hstack((x, x.sum(axis=1).reshape(-1, 1)))
    dx = np.diff(self.x[self.triangles], axis=1)
    dy = np.diff(self.y[self.triangles], axis=1)
    return np.sqrt((merge(dx)**2) + (merge(dy)**2)).max(axis=1)

# %%
plt.triplot(pop.triangulation, 'bo-', lw=1, markersize=3, alpha=0.1)

# %%
plt.triplot(pop.triangulation, 'bo-', lw=1, markersize=3, alpha=0.1)
# Out:
# [<matplotlib.lines.Line2D at 0x112512940>,
#  <matplotlib.lines.Line2D at 0x112512a90>]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
pop.plot(ax)

ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)


parent = '0'
descendents = np.array([lineage.startswith(parent) for lineage in pop.lineages])
descendents_xy = pop.xy[descendents]

ax.scatter(*descendents_xy.T, c='r', s=50)

# %%
parent = '000'
for child in G.neighbors(parent):
    print(child)
# Out:
# 0000
# 0001

# %%
successors = nx.nodes(nx.dfs_tree(G, your_node))
# Out:
# <bound method DiGraph.successors of <networkx.classes.digraph.DiGraph object at 0x112d897f0>>

# %%
nx.dfs_tree(G, parent)

# %%
parent = '00001'
successors = nx.dfs_successors(G, source=parent)


predecessors = nx.dfs_predecessors(G, parent).keys()

# %%
end = list(set(predecessors).difference(set(successors)))

# %%
a = '00132213'

# %%
a
# Out:
# True

# %%
nx.kamada_kawai_layout

# %%
G = nx.DiGraph(dendrogram)

# %%
nx.draw_kamada_kawai(G, node_size=10, with_labels=False)
